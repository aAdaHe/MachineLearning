# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 6.5 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('1_LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('1_LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://sporoid-nonnegligibly-casie.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://sporoid-nonnegligibly-casie.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# AI Agent（人工智慧代理人）是一個能夠**感知環境、做出決策、並執行動作以達成特定目標**的軟體或硬體實體。它代表了將人工智慧技術應用於特定任務或環境中的一種具體形式。
#
# 簡單來說，你可以把 AI Agent 想像成一個「智能小助手」，它有眼睛（感知）、有大腦（思考/決策），也有手腳（行動），並且知道自己要完成什麼任務。
#
# ### AI Agent 的關鍵特徵：
#
# 1.  **感知 (Perception)：**
#     *   能夠從其操作的環境中收集資訊。對於軟體代理人，這可能是透過API、資料庫、感測器數據、使用者輸入、文本等。對於硬體代理人（如機器人），這可能是透過攝影機、麥克風、觸控感測器等。
#
# 2.  **思考/決策 (Reasoning/Decision-making)：**
#     *   根據感知的資訊、內部的知識庫、規則、演算法或AI模型（如大型語言模型LLM），對當前狀態進行分析，並規劃下一步的行動。這包括解決問題、規劃路徑、預測結果等。
#
# 3.  **行動 (Action)：**
#     *   能夠在環境中執行實際的操作。對於軟體代理人，這可能是發送電子郵件、更新資料庫、執行命令、生成文本、控制其他軟體等。對於硬體代理人，這可能是移動、抓取物體、發出聲音等。
#
# 4.  **目標導向 (Goal-oriented)：**
#     *   每個AI Agent 都設定了一個或多個明確的目標，其所有的感知、思考和行動都是為了實現這些目標。
#
# 5.  **自主性 (Autonomy)：**
#     *   Agent 可以在沒有持續人工干預的情況下獨立運作一段時間，並根據環境變化做出調整。
#
# 6.  **環境 (Environment)：**
#     *   Agent 操作的上下文或世界。環境可以是虛擬的（如電腦系統、網路世界）或物理的（如現實世界）。
#
# ### 實際範例：
#
# *   **智能助理（如Siri, Alexa, Google Assistant, ChatGPT等）：**
#     *   **感知：** 語音指令、文字輸入。
#     *   **思考：** 理解使用者意圖、查詢資訊、規劃回應。
#     *   **行動：** 回答問題、播放音樂、設定提醒、控制智能家居設備。
#     *   **目標：** 協助使用者完成各種任務。
#
# *   **推薦系統（如Netflix、Amazon）：**
#     *   **感知：** 你的觀看/購物歷史、評分、瀏覽行為。
#     *   **思考：** 分析你的偏好，與其他用戶比較。
#     *   **行動：** 推薦電影、商品。
#     *   **目標：** 提高用戶參與度，促進銷售。
#
# *   **自動駕駛汽車：**
#     *   **感知：** 攝影機、雷達、光學雷達、GPS等感測器數據。
#     *   **思考：** 識別路況、障礙物、交通標誌、預測行人行為，規劃行車路徑。
#     *   **行動：** 加速、煞車、轉向。
#     *   **目標：** 安全、高效地將乘客從A點運送到B點。
#
# *   **客服聊天機器人：**
#     *   **感知：** 使用者輸入的文字。
#     *   **思考：** 理解問題、查詢知識庫、判斷解決方案。
#     *   **行動：** 回覆問題、引導用戶、轉接人工客服。
#     *   **目標：** 解決用戶疑問，提供支援。
#
# *   **軟體自動化代理人 (RPA Agents)：**
#     *   **感知：** 電腦畫面、應用程式介面。
#     *   **思考：** 遵循預設規則或學習模式。
#     *   **行動：** 自動化重複性任務，如數據輸入、報告生成、文件處理。
#     *   **目標：** 提高工作效率，減少人為錯誤。
#
# ### 總結：
#
# AI Agent 是人工智慧實用化的體現，它將感知、決策和行動整合在一起，使其能夠在複雜的環境中自主運作，並有效地實現預設的目標。隨著大型語言模型（LLM）的發展，AI Agent 變得更加強大和通用，能夠處理更複雜、更開放式的任務。

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學 (Ming Hsin University of Science and Technology, MHUST) 是一所位於台灣**新竹縣新豐鄉**的私立科技大學。
#
# 以下是其簡要介紹：
#
# 1.  **創校歷史與沿革**：
#     *   創立於**1966年**，前身為「**明新工業專科學校**」，是台灣第一所私立工業專科學校。
#     *   歷經「明新技術學院」階段，於**2002年**改制為現今的「**明新科技大學**」。
#
# 2.  **地理位置優勢**：
#     *   明新科大位於新竹縣，**鄰近新竹科學園區**，這一地理優勢使其與周邊高科技產業及其他產業鏈緊密結合。
#     *   這為學生提供了豐富的**實習、產學合作與就業機會**，特別是在工程和管理領域。
#
# 3.  **教育理念與特色**：
#     *   學校秉持「**誠信、明新、致用、創新**」的校訓精神，以「**務實致用**」為導向。
#     *   致力於培養具備**專業技能、職場競爭力及創新思維**的人才。
#     *   **強調產學合作**，注重理論與實務的結合，課程設計與產業需求緊密連結，讓學生在畢業前就能累積實務經驗。
#
# 4.  **學術組織與系所**：
#     *   明新科大設有多個學院，包括：
#         *   **工程學院**
#         *   **管理學院**
#         *   **服務事業管理學院** (餐旅管理、旅館管理等)
#         *   **設計學院**
#         *   **人文社會學院**
#     *   提供學士班、碩士班等學位課程，涵蓋工程、管理、餐旅、設計、人文社會等多元領域。
#
# 5.  **綜合評價**：
#     *   明新科技大學在技職教育領域扮演重要角色，以其務實的教學風格、良好的就業率，尤其是在新竹地區，為台灣的產業發展培育了無數優秀的專業技術與管理人才。

# %%
result = stateless_query("校長室誰")
print(result)
# Out:
# 校長室には、基本的には**校長先生**がいらっしゃいます。
#
# その他には、時間帯や状況によって、以下のような方がいる可能性があります。
#
# *   **教職員（先生方）**: 会議や報告、相談などで校長先生と話している場合。
# *   **生徒**: 表彰や面談、指導などで校長先生に呼ばれている場合。
# *   **保護者**: 相談や学校行事の打ち合わせなどで来訪している場合。
# *   **来客**: 他の学校関係者や業者などが校長先生と面会している場合。
# *   **事務員**: 校長室での業務を手伝っている場合。
#
# といった形です。特定の校長室の状況は分かりかねますので、一般的な回答になります。

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '):  #這邊有限定AI 開頭的才會用gemini回答
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [22/May/2026 02:37:40] "POST / HTTP/1.1" 200 -
# BODY:  {"destination":"U3169a962e22ea2afc45f6eb98941b9c1","events":[]}
# BODY:  {"destination":"U3169a962e22ea2afc45f6eb98941b9c1","events":[{"type":"message","message":{"type":"text","id":"615029521879400468","quoteToken":"cD2RFVDgh-65Vg1S69euDMlFA1gCu-dPfRj6WF2t7Zode4k5EBuY3wSV2PPFcBbVO5WQDHPMYI7H33M7fYFHaVkhy19CSPbRL_uBPq-MbtQz9SqhlaiD6wQXxidJ8uGjvwhVIW6gLARqb7WandobyA","markAsReadToken":"72gXMzAxs7k1dE4JEyALRxy5JwEnTACdDy0xD6JbUyo7TcVcqnqQ_i3-uXFbPH6Etsa-dWLe5W85vr2sDgLEpe99_g3wwe3dHQYHkIDSTvtgCajQZTdzEOKVPir5_E3LLuNxsafrVY7TyJiHRInkjhfWf9rr416HvaLkKGULcvy5igPNO_aiS2KXNsLfxjhPNSBE-jd5rMEdZOAlQw4LDg","text":"簡介明新科技大學"},"webhookEventId":"01KS6RQHE02NJSSS1F2XD3PAAE","deliveryContext":{"isRedelivery":false},"timestamp":1779417465966,"source":{"type":"user","userId":"Uc736f30f5abec3489b5e495c080336e4"},"replyToken":"4f3ceba5337c4bcfb639073274de1608","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [22/May/2026 02:37:46] "POST / HTTP/1.1" 200 -
# BODY:  {"destination":"U3169a962e22ea2afc45f6eb98941b9c1","events":[{"type":"message","message":{"type":"text","id":"615029532634120772","quoteToken":"E47hkhmo4XKPO5U87Z8DZGGkw64ljR1tE2Pb3mPhWy1uxcIrKb8iGxnADo00mr9zYDPnopzM5CXstneSPSnrSblSylQGMfoJv9TWjpH0eSZxgvf9rBrI5LGz0RiphTgm5Q2r-DWQwGTynSmgPfA2xg","markAsReadToken":"STsm-X9JApw62hFzJzsjdsYCO9JkPAgNz9hS3NMv5Sgqli9PErqZ5vtDAWALlF1CYwGNrs45K9HGDJfdtLOtCk3WQyQ7XmgM4dVCUcNal_PPVv-nb0Dcwg8YKQN4TKZ-79T3FUVwFYi34tP0W0-uIKVlTdIuUPJldc0kB5LGzltG11_kyNVtQ7xP4MNLe12vmKIELJPtu_yIFrIXN6b1VA","text":"AI 簡介明新科技大學"},"webhookEventId":"01KS6RQQDG4F4VK09YDP6GHM0R","deliveryContext":{"isRedelivery":false},"timestamp":1779417472307,"source":{"type":"user","userId":"Uc736f30f5abec3489b5e495c080336e4"},"replyToken":"762dd12b1a5d46d6a1d0782265bdd7bf","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [22/May/2026 02:38:04] "POST / HTTP/1.1" 200 -
